# %%
from train_model_2 import train_model

# %%
model, X_test, y_test = train_model()
# Out:
# Epoch 1/20
# 97/97 [==============================] - 0s 3ms/step - loss: 1.5937 - accuracy: 0.2474
# Epoch 2/20
# 97/97 [==============================] - 0s 51us/step - loss: 1.5149 - accuracy: 0.3299
# Epoch 3/20
# 97/97 [==============================] - 0s 51us/step - loss: 1.4530 - accuracy: 0.5361
# Epoch 4/20
# 97/97 [==============================] - 0s 51us/step - loss: 1.4025 - accuracy: 0.6495
# Epoch 5/20
# 97/97 [==============================] - 0s 51us/step - loss: 1.3535 - accuracy: 0.7113
# Epoch 6/20
# 97/97 [==============================] - 0s 51us/step - loss: 1.3131 - accuracy: 0.7732
# Epoch 7/20
# 97/97 [==============================] - 0s 51us/step - loss: 1.2777 - accuracy: 0.7835
# Epoch 8/20
# 97/97 [==============================] - 0s 51us/step - loss: 1.2415 - accuracy: 0.7938
# Epoch 9/20
# 97/97 [==============================] - 0s 41us/step - loss: 1.1999 - accuracy: 0.8557
# Epoch 10/20
# ...

# %%
results = model.evaluate(X_test,y_test)
# Out:
# 25/25 [==============================] - 0s 3ms/step

# %%
results
# Out:
# [0.9280700087547302, 0.8799999952316284]

# %%
model.predict(X_test)
# Out:
# array([[1.58985347e-01, 2.41519228e-01, 1.73918918e-01, 2.51195967e-01,
#         1.74380541e-01],
#        [1.55454129e-01, 1.74670175e-01, 1.49627090e-01, 1.86023965e-01,
#         3.34224641e-01],
#        [1.77468315e-01, 2.05722451e-01, 3.07969391e-01, 1.51488379e-01,
#         1.57351464e-01],
#        [1.80251032e-01, 1.76133901e-01, 1.23376675e-01, 1.43180221e-01,
#         3.77058119e-01],
#        [1.80251032e-01, 1.76133901e-01, 1.23376675e-01, 1.43180221e-01,
#         3.77058119e-01],
#        [9.49695259e-02, 1.58188835e-01, 8.26859400e-02, 1.89575389e-01,
#         4.74580348e-01],
#        [2.02649891e-01, 4.68372732e-01, 1.96992472e-01, 7.44579732e-02,
#         5.75269088e-02],
#        [1.54476255e-01, 1.89859390e-01, 4.75883663e-01, 1.01631634e-01,
#         7.81490728e-02],
#        [9.14036483e-02, 2.89245158e-01, 1.55354917e-01, 3.30893040e-01,
#         1.33103266e-01],
#        [7.57456049e-02, 7.68993497e-01, 1.54261813e-01, 7.41983007e-04,
# ...
