# %%
from train_model_5 import train_model

# %%
import numpy as np

# %%
model, X_test, y_test = train_model()
# Out:
# Epoch 1/20
# 96/96 [==============================] - 0s 712us/step - loss: 1.7013 - accuracy: 0.1771
# Epoch 2/20
# 96/96 [==============================] - 0s 20us/step - loss: 1.5575 - accuracy: 0.2500
# Epoch 3/20
# 96/96 [==============================] - 0s 21us/step - loss: 1.4881 - accuracy: 0.3750
# Epoch 4/20
# 96/96 [==============================] - 0s 10us/step - loss: 1.4301 - accuracy: 0.3958
# Epoch 5/20
# 96/96 [==============================] - 0s 31us/step - loss: 1.3796 - accuracy: 0.4479
# Epoch 6/20
# 96/96 [==============================] - 0s 21us/step - loss: 1.3352 - accuracy: 0.5521
# Epoch 7/20
# 96/96 [==============================] - 0s 20us/step - loss: 1.2949 - accuracy: 0.5938
# Epoch 8/20
# 96/96 [==============================] - 0s 11us/step - loss: 1.2570 - accuracy: 0.6771
# Epoch 9/20
# 96/96 [==============================] - 0s 21us/step - loss: 1.2217 - accuracy: 0.6979
# Epoch 10/20
# ...

# %%
results = model.evaluate(X_test,y_test)
# Out:
# 24/24 [==============================] - 0s 957us/step

# %%
results
# Out:
# [1.1110960245132446, 0.6666666865348816]

# %%
model.predict(X_test)
# Out:
# array([[0.00660879, 0.98770267, 0.00177215, 0.00167058, 0.00224588],
#        [0.15782736, 0.18881963, 0.30015323, 0.22502497, 0.12817481],
#        [0.14261696, 0.43963256, 0.13312814, 0.14056627, 0.14405599],
#        [0.11104868, 0.12372162, 0.11453077, 0.11818857, 0.53251034],
#        [0.18621783, 0.18586892, 0.16246676, 0.16590333, 0.29954317],
#        [0.18336715, 0.12513359, 0.15441197, 0.116845  , 0.4202423 ],
#        [0.10514906, 0.58405596, 0.09070721, 0.09512025, 0.1249675 ],
#        [0.14272869, 0.25740537, 0.1865861 , 0.24978769, 0.16349226],
#        [0.14598018, 0.15703993, 0.30314586, 0.2101783 , 0.1836557 ],
#        [0.11104868, 0.12372162, 0.11453077, 0.11818857, 0.53251034],
#        [0.25524178, 0.167024  , 0.18129377, 0.13696006, 0.25948036],
#        [0.29713964, 0.15642267, 0.1927732 , 0.09634753, 0.25731698],
#        [0.34961876, 0.13657643, 0.28613237, 0.07882413, 0.14884825],
#        [0.10134736, 0.6059715 , 0.07927024, 0.11233966, 0.10107115],
# ...
